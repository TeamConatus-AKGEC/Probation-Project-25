# %% [markdown]
# <a href="https://colab.research.google.com/github/ritikakatta24-beep/Probation-Project-25/blob/task/Ritika_katta_task7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("/content/Fuel Cosumption - Sheet1.csv")

# %%
df.shape
# Out:
# (639, 10)

# %%
df.head()
# Out:
#    Year   MAKE    MODEL VEHICLE CLASS  ENGINE SIZE  CYLINDERS TRANSMISSION  \
# 0  2000  ACURA    1.6EL       COMPACT          1.6          4           A4
# 1  2000  ACURA    1.6EL       COMPACT          1.6          4           M5
# 2  2000  ACURA    3.2TL      MID-SIZE          3.2          6          AS5
# 3  2000  ACURA    3.5RL      MID-SIZE          3.5          6           A4
# 4  2000  ACURA  INTEGRA    SUBCOMPACT          1.8          4           A4
#
#   FUEL  FUEL CONSUMPTION  COEMISSIONS
# 0    X              10.5          216
# 1    X               9.8          205
# 2    Z              13.7          265
# 3    Z              15.0          301
# 4    X              11.4          230

# %%
df.tail()
# Out:
#      Year   MAKE           MODEL             VEHICLE CLASS  ENGINE SIZE  \
# 634  2000  VOLVO   V70 AWD TURBO  STATION WAGON - MID-SIZE          2.4
# 635  2000  VOLVO   V70 GLT TURBO  STATION WAGON - MID-SIZE          2.4
# 636  2000  VOLVO    V70 T5 TURBO  STATION WAGON - MID-SIZE          2.3
# 637  2000  VOLVO    V70 T5 TURBO  STATION WAGON - MID-SIZE          2.3
# 638  2000  VOLVO  V70R AWD TURBO  STATION WAGON - MID-SIZE          2.4
#
#      CYLINDERS TRANSMISSION FUEL  FUEL CONSUMPTION  COEMISSIONS
# 634          5           A4    Z              14.4          288
# 635          5           A4    Z              13.6          274
# 636          5           A4    Z              13.9          274
# 637          5           M5    Z              13.0          260
# 638          5           A5    Z              14.7          299

# %%
df.sample(7)
# Out:
#      Year        MAKE             MODEL            VEHICLE CLASS  ENGINE SIZE  \
# 603  2000  VOLKSWAGEN  JETTA TDI DIESEL                  COMPACT          1.9
# 352  2000       ISUZU         RODEO 4X4                      SUV          3.2
# 61   2000       BUICK           LESABRE                FULL-SIZE          3.8
# 20   2000        AUDI        A6 QUATTRO                 MID-SIZE          2.7
# 264  2000        FORD            RANGER  PICKUP TRUCK - STANDARD          4.0
# 539  2000      TOYOTA       4RUNNER 4X4                      SUV          2.7
# 256  2000        FORD     GRAND MARQUIS                FULL-SIZE          4.6
#
#      CYLINDERS TRANSMISSION FUEL  FUEL CONSUMPTION  COEMISSIONS
# 603          4           M5    D               6.7          165
# 352          6           M5    X              16.8          347
# 61           6           A4    X              13.8          265
# 20           6           M6    Z              15.2          304
# 264          6           A5    X              17.0          354
# 539          4           A4    X              14.2          301
# 256          8           A4    X              15.0          297

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 639 entries, 0 to 638
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Year              639 non-null    int64
#  1   MAKE              639 non-null    object
#  2   MODEL             639 non-null    object
#  3   VEHICLE CLASS     639 non-null    object
#  4   ENGINE SIZE       639 non-null    float64
#  5   CYLINDERS         639 non-null    int64
#  6   TRANSMISSION      639 non-null    object
#  7   FUEL              639 non-null    object
#  8   FUEL CONSUMPTION  639 non-null    float64
#  9   COEMISSIONS       639 non-null    int64
# dtypes: float64(2), int64(3), object(5)
# memory usage: 50.1+ KB

# %%
df.describe()
# Out:
#          Year  ENGINE SIZE   CYLINDERS  FUEL CONSUMPTION  COEMISSIONS
# count   639.0   639.000000  639.000000        639.000000   639.000000
# mean   2000.0     3.265728    5.805947         14.713615   296.809077
# std       0.0     1.231012    1.625588          3.307044    65.504178
# min    2000.0     1.000000    3.000000          4.900000   104.000000
# 25%    2000.0     2.200000    4.000000         12.500000   253.000000
# 50%    2000.0     3.000000    6.000000         14.400000   288.000000
# 75%    2000.0     4.300000    6.000000         16.600000   343.000000
# max    2000.0     8.000000   12.000000         30.200000   582.000000

# %%
df.duplicated().sum()
# Out:
# np.int64(1)

# %%
df[df.duplicated()]
# Out:
#      Year        MAKE                    MODEL VEHICLE CLASS  ENGINE SIZE  \
# 378  2000  LAND ROVER  DISCOVERY SERIES II 4X4           SUV          4.0
#
#      CYLINDERS TRANSMISSION FUEL  FUEL CONSUMPTION  COEMISSIONS
# 378          8           A4    Z              19.6          403

# %%
df = df.drop_duplicates()

# %%
df.shape
# Out:
# (638, 10)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.columns = df.columns.str.strip().str.replace(" ", "_")

# %%
df.head()
# Out:
#    Year   MAKE    MODEL VEHICLE_CLASS  ENGINE_SIZE  CYLINDERS TRANSMISSION  \
# 0  2000  ACURA    1.6EL       COMPACT          1.6          4           A4
# 1  2000  ACURA    1.6EL       COMPACT          1.6          4           M5
# 2  2000  ACURA    3.2TL      MID-SIZE          3.2          6          AS5
# 3  2000  ACURA    3.5RL      MID-SIZE          3.5          6           A4
# 4  2000  ACURA  INTEGRA    SUBCOMPACT          1.8          4           A4
#
#   FUEL  FUEL_CONSUMPTION  COEMISSIONS
# 0    X              10.5          216
# 1    X               9.8          205
# 2    Z              13.7          265
# 3    Z              15.0          301
# 4    X              11.4          230

# %%
numeric_cols = ['ENGINE_SIZE', 'CYLINDERS', 'FUEL_CONSUMPTION', 'COEMISSIONS']
sns.boxplot(data=df[numeric_cols])
plt.title('Boxplots of Numeric Columns')
plt.show()

# %%
sns.boxplot(data=df,y='COEMISSIONS')
# Out:
# <Axes: ylabel='COEMISSIONS'>

# %%
sns.boxplot(data=df,y='CYLINDERS')
# Out:
# <Axes: ylabel='CYLINDERS'>

# %%
sns.boxplot(data=df,y='FUEL_CONSUMPTION')
# Out:
# <Axes: ylabel='FUEL_CONSUMPTION'>

# %%
sns.boxplot(data=df,y='ENGINE_SIZE')
# Out:
# <Axes: ylabel='ENGINE_SIZE'>

# %%
percentile25 = df['COEMISSIONS'].quantile(0.25)
percentile75 = df['COEMISSIONS'].quantile(0.75)

# %%
percentile25
# Out:
# np.float64(253.0)

# %%
iqr = percentile75 - percentile25

# %%
iqr
# Out:
# np.float64(90.0)

# %%
upper_limit = percentile75 + 1.5 * iqr
lower_limit = percentile25 - 1.5 * iqr

# %%
lower_limit
# Out:
# np.float64(118.0)

# %%
upper_limit
# Out:
# np.float64(478.0)

# %%
new_df = df.copy()

new_df['COEMISSIONS'] = np.where(
    new_df['COEMISSIONS'] > upper_limit,
    upper_limit,
    np.where(
        new_df['COEMISSIONS'] < lower_limit,
        lower_limit,
        new_df['COEMISSIONS']
    )
)

# %%
new_df.shape
# Out:
# (638, 10)

# %%
sns.boxplot(data=new_df,y='COEMISSIONS')
# Out:
# <Axes: ylabel='COEMISSIONS'>

# %%
percentile25 = df['FUEL_CONSUMPTION'].quantile(0.25)
percentile75 = df['FUEL_CONSUMPTION'].quantile(0.75)

# %%
iqr=percentile75-percentile25

# %%
upper_limit=percentile75+1.5*iqr
lower_limit=percentile25-1.5*iqr

# %%
new_df = df.copy()

new_df['FUEL_CONSUMPTION'] = np.where(
    new_df['FUEL_CONSUMPTION'] > upper_limit,
    upper_limit,
    np.where(
        new_df['FUEL_CONSUMPTION'] < lower_limit,
        lower_limit,
        new_df['FUEL_CONSUMPTION']
    )
)

# %%
sns.boxplot(data=new_df,y='FUEL_CONSUMPTION')
# Out:
# <Axes: ylabel='FUEL_CONSUMPTION'>

# %%
percentile25 = df['CYLINDERS'].quantile(0.25)
percentile75 = df['CYLINDERS'].quantile(0.75)

# %%
iqr=percentile75-percentile25

# %%
upper_limit=percentile75+1.5*iqr
lower_limit=percentile25-1.5*iqr

# %%
new_df = df.copy()

new_df['CYLINDERS'] = np.where(
    new_df['CYLINDERS'] > upper_limit,
    upper_limit,
    np.where(
        new_df['CYLINDERS'] < lower_limit,
        lower_limit,
        new_df['CYLINDERS']
    )
)

# %%
sns.boxplot(data=new_df,y='CYLINDERS')
# Out:
# <Axes: ylabel='CYLINDERS'>

# %%
percentile25 = df['ENGINE_SIZE'].quantile(0.25)
percentile75 = df['ENGINE_SIZE'].quantile(0.75)

# %%
iqr=percentile75-percentile25

# %%
upper_limit=percentile75+1.5*iqr
lower_limit=percentile25-1.5*iqr

# %%
new_df = df.copy()

new_df['ENGINE_SIZE'] = np.where(
    new_df['ENGINE_SIZE'] > upper_limit,
    upper_limit,
    np.where(
        new_df['ENGINE_SIZE'] < lower_limit,
        lower_limit,
        new_df['ENGINE_SIZE']
    )
)

# %%
sns.boxplot(data=new_df,y='ENGINE_SIZE')
# Out:
# <Axes: ylabel='ENGINE_SIZE'>

# %%
plt.hist(df['ENGINE_SIZE'])
plt.xlabel('ENGINE_SIZE')
plt.ylabel('Frequency')
plt.title('Distribution of Engine size')
plt.show()

# %%
plt.hist(df['FUEL_CONSUMPTION'])
plt.xlabel('FUEL_CONSUMPTION')
plt.ylabel('Frequency')
plt.title('Distribution of FUEL_CONSUMPTION')
plt.show()

# %%
plt.scatter(df['FUEL_CONSUMPTION'],df['COEMISSIONS'],marker='o',color='violet')
plt.xlabel('Fuel consumption')
plt.ylabel('COEMISSIONS')
plt.show()

# %%
plt.scatter(df['ENGINE_SIZE'],df['COEMISSIONS'],marker='o',color='violet')
plt.xlabel('Engine size')
plt.ylabel('COEMISSIONS')
plt.show()

# %%
plt.figure(figsize=(7,6))
sns.heatmap(df[['FUEL_CONSUMPTION', 'COEMISSIONS']].corr(), annot=True, cmap='coolwarm',linewidths=0.5)
plt.title('Correlation Heatmap: Fuel Consumption vs CoEmissions')
plt.show()

# %%
X=df.iloc[:,8:9]
y = df.iloc[:,-1]

# %%
X
# Out:
#      FUEL_CONSUMPTION
# 0                10.5
# 1                 9.8
# 2                13.7
# 3                15.0
# 4                11.4
# ..                ...
# 634              14.4
# 635              13.6
# 636              13.9
# 637              13.0
# 638              14.7
#
# [638 rows x 1 columns]

# %%
y
# Out:
# 0      216
# 1      205
# 2      265
# 3      301
# 4      230
#       ...
# 634    288
# 635    274
# 636    274
# 637    260
# 638    299
# Name: COEMISSIONS, Length: 638, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
X_test
# Out:
#      FUEL_CONSUMPTION
# 587              11.1
# 392              21.4
# 1                 9.8
# 67               15.5
# 84               17.9
# ..                ...
# 389              15.4
# 109              18.0
# 142              14.4
# 231              20.2
# 472              13.6
#
# [128 rows x 1 columns]

# %%
y_test
# Out:
# 587    225
# 392    430
# 1      205
# 67     297
# 84     373
#       ...
# 389    304
# 109    377
# 142    283
# 231    403
# 472    262
# Name: COEMISSIONS, Length: 128, dtype: int64

# %%
lr.predict(X_test.iloc[0].values.reshape(1,1))
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([226.63769631])

# %%
plt.scatter(df['FUEL_CONSUMPTION'],df['COEMISSIONS'],marker='o',color='violet')
plt.plot(X_train,lr.predict(X_train),color='red')
plt.xlabel('Fuel consumption')
plt.ylabel('COEMISSIONS')
plt.show()

# %%
X=df.iloc[:,4:5]
y = df.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
X_test
# Out:
#      ENGINE_SIZE
# 587          1.8
# 392          5.4
# 1            1.6
# 67           4.6
# 84           5.3
# ..           ...
# 389          3.0
# 109          5.3
# 142          3.5
# 231          5.4
# 472          3.4
#
# [128 rows x 1 columns]

# %%
y_test
# Out:
# 587    225
# 392    430
# 1      205
# 67     297
# 84     373
#       ...
# 389    304
# 109    377
# 142    283
# 231    403
# 472    262
# Name: COEMISSIONS, Length: 128, dtype: int64

# %%
lr.predict(X_test.iloc[0].values.reshape(1,1))
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([230.25548515])

# %%
plt.scatter(df['ENGINE_SIZE'],df['COEMISSIONS'],marker='o',color='violet')
plt.plot(X_train,lr.predict(X_train),color='red')
plt.xlabel('Engine size')
plt.ylabel('COEMISSIONS')
plt.show()

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
y_pred = lr.predict(X_test)

# %%
print("MAE",mean_absolute_error(y_test,y_pred))
# Out:
# MAE 22.01834605283994

# %%
print("MSE",mean_squared_error(y_test,y_pred))
# Out:
# MSE 838.7422956497577

# %%
print("RMSE",np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# RMSE 28.96104790317087

# %%
print("R2_SCORE",r2_score(y_test,y_pred))
r2 = r2_score(y_test,y_pred)
# Out:
# R2_SCORE 0.7714171510316332
